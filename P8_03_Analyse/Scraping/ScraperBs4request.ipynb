# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c&tab=stats")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <title>
#    Match History
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="nosniff" http-equiv="X-Content-Type-Options">
#    <meta content="SAMEORIGIN" http-equiv="X-Frame-Options"/>
#    <link href="//cdn.leagueoflegends.com/lolkit/1.1.5/resources/images/favicon.ico" rel="icon" type="image/x-icon"/>
#    <link href="//cdn.leagueoflegends.com/lolkit/1.1.5/resources/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="//cdn.leagueoflegends.com/lolkit/1.1.5/lol-kit.css" rel="stylesheet"/>
#    <link href="../assets/1.0.38/css/styles.normal.css" rel="stylesheet" type="text/css"/>
#    <meta content="League of Legends Match History" property="og:title"/>
#    <meta content="https://cdn.leagueoflegends.com/match-history/opengraph_icon.jpg" property="og:image"/>
# ...
