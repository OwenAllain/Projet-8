# %%
import pandas as pd
df = pd.read_csv("../../../Data/DataRaw/set_monsters.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44248 entries, 0 to 44247
# Data columns (total 4 columns):
# Address    44248 non-null object
# Team       44248 non-null object
# Time       44248 non-null float64
# Type       44248 non-null object
# dtypes: float64(1), object(3)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (44248, 4)

# %%
df.tail()
# Out:
#                                                  Address      Team    Time  \
# 44243  https://matchhistory.na.leagueoflegends.com/en...  rHeralds  17.307
# 44244  https://matchhistory.na.leagueoflegends.com/en...  rHeralds  14.191
# 44245  https://matchhistory.br.leagueoflegends.com/pt...  rHeralds  16.258
# 44246  https://matchhistory.euw.leagueoflegends.com/e...  rHeralds  17.243
# 44247  https://matchhistory.na.leagueoflegends.com/en...  rHeralds  16.912
#
#               Type
# 44243  RIFT_HERALD
# 44244  RIFT_HERALD
# 44245  RIFT_HERALD
# 44246  RIFT_HERALD
# 44247  RIFT_HERALD

# %%
df.Type.value_counts()[["FIRE_DRAGON","EARTH_DRAGON","WATER_DRAGON","AIR_DRAGON","ELDER_DRAGON"]].plot.bar(figsize=(15,10), rot=45)
plt.savefig

# %%
df.groupby(["Team","Type"]).size().plot.bar(figsize=(15,10))
