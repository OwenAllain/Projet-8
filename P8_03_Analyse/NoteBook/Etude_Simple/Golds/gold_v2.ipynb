# %%
import pandas as pd
import numpy as np
import seaborn as sns


import matplotlib.pyplot as plt
import datetime as dt



df = pd.read_csv("../../../Data/DataRaw/set_gold.csv")

# %%
df
# Out:
#                                                  Address            Type  \
# 0      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 1      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 2      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 3      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 4      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# ...                                                  ...             ...
# 99055  https://matchhistory.euw.leagueoflegends.com/e...  goldredSupport
# 99056  https://matchhistory.euw.leagueoflegends.com/e...  goldredSupport
# 99057  https://matchhistory.na.leagueoflegends.com/en...  goldredSupport
# 99058  https://matchhistory.na.leagueoflegends.com/en...  goldredSupport
# 99059  https://matchhistory.na.leagueoflegends.com/en...  goldredSupport
#
#        min_1  min_2  min_3  min_4  min_5  min_6  min_7  min_8  ...  min_86  \
# ...

# %%
df.Type.unique()
# Out:
# array(['golddiff', 'goldblue', 'goldred', 'goldblueTop', 'goldblueJungle',
#        'goldblueMiddle', 'goldblueADC', 'goldblueSupport', 'goldredTop',
#        'goldredJungle', 'goldredMiddle', 'goldredADC', 'goldredSupport'],
#       dtype=object)

# %%
gold_blue = df.query("Type == 'goldblue' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_red = df.query("Type == 'goldred' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_red_b = gold_red.drop(columns = ["Type","Address"])
gold_blue_b = gold_blue.drop(columns = ["Type","Address"])

# %%
gold_red_b
# Out:
#        min_1  min_2  min_3  min_4  min_5  min_6  min_7  min_8  min_9  min_10  \
# 15240   2415   2415   2725   3952   5336   6602   7900   9450  10648   11986
#
#        ...  min_86  min_87  min_88  min_89  min_90  min_91  min_92  min_93  \
# 15240  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#        min_94  min_95
# 15240     NaN     NaN
#
# [1 rows x 95 columns]

# %%
gold_blue = df.query("Type == 'goldblue' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_blue_adc = df.query("Type == 'goldblueADC' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_blue_top = df.query("Type == 'goldblueTop' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_blue_mid = df.query("Type == 'goldblueMiddle' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_blue_jug = df.query("Type == 'goldblueJungle' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")
gold_blue_sup = df.query("Type == 'goldblueSupport' & Address == 'http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/30030?gameHash=fbb300951ad8327c'")

gold_blue_b = gold_blue.drop(columns = ["Type","Address"])
gold_blue_adc_b = gold_blue_adc.drop(columns = ["Type","Address"])
gold_blue_top_b = gold_blue_top.drop(columns = ["Type","Address"])
gold_blue_mid_b = gold_blue_mid.drop(columns = ["Type","Address"])
gold_blue_jug_b = gold_blue_jug.drop(columns = ["Type","Address"])
gold_blue_sup_b = gold_blue_sup.drop(columns = ["Type","Address"])

# %%
plt.figure(figsize=(15,15))
# plt.hist(gold_blue_b,alpha=0.5)
# plt.hist(gold_blue_adc_b,alpha=0.5)
# plt.hist(gold_blue_top_b,alpha=0.5)
plt.hist(gold_blue_mid_b,alpha=0.5)
# plt.hist(gold_blue_jug_b,alpha=0.5)
# plt.hist(gold_blue_sup_b,alpha=0.5)
plt.show()
# Out:
# /home/kozame/.local/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/kozame/.local/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
